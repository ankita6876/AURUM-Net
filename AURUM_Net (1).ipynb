# %% [markdown]
# # AURUM-Net: Regime-Gated Uncertainty-Aware Gold Price Forecasting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("Gold Price.csv")

df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')
df.set_index('Date', inplace=True)

df.head()
df.tail()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3104 entries, 2014-01-01 to 2026-01-02
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   3104 non-null   int64
#  1   Open    3104 non-null   int64
#  2   High    3104 non-null   int64
#  3   Low     3104 non-null   int64
#  4   Volume  3104 non-null   int64
#  5   Chg%    3104 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 169.8 KB

# %%
print(df.columns)
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Volume', 'Chg%'], dtype='object')

# %%
df.reset_index(inplace=True)
df.rename(columns={'index': 'Date'}, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df = df.dropna(subset=['Date'])
df = df.sort_values('Date')
df.set_index('Date', inplace=True) # Set 'Date' as index after cleaning and sorting

# %%
print(df.index.min())
print(df.index.max())
# Out:
# 2014-01-01 00:00:00
# 2026-01-02 00:00:00

# %%
# Rename for financial convention
df.rename(columns={'Price': 'Close'}, inplace=True)

# Convert Chg% to float (if not already)
df['Chg%'] = df['Chg%'].astype(float)

# This line was creating an artificial index, causing a date mismatch.
# Removed: df.index = pd.date_range(start='2000-01-01', periods=len(df), freq='D')

df.head()
# Out:
#             Close   Open   High    Low  Volume  Chg%
# Date
# 2014-01-01  29542  29435  29598  29340    2930  0.25
# 2014-01-02  29975  29678  30050  29678    3140  1.47
# 2014-01-03  29727  30031  30125  29539    3050 -0.83
# 2014-01-04  29279  29279  29279  29279       0 -1.51
# 2014-01-06  29119  29300  29395  29051   24380 -0.55

# %% [markdown]
# #Feature Engineering (Regime-Sensitive)

# %%
# Log returns
df['Log_Return'] = np.log(df['Close'] / df['Close'].shift(1))

# Volatility (rolling)
df['Volatility'] = df['Log_Return'].rolling(14).std()

# Technical indicators
df['MA_10'] = df['Close'].rolling(10).mean()
df['MA_30'] = df['Close'].rolling(30).mean()

# Price range pressure
df['HL_Range'] = df['High'] - df['Low']
df['OC_Change'] = df['Open'] - df['Close']

df.dropna(inplace=True)

# %%
from sklearn.mixture import GaussianMixture

regime_features = df[['Log_Return', 'Volatility']].dropna()

gmm = GaussianMixture(n_components=3, covariance_type='full', random_state=42)
gmm_regime_labels = gmm.fit_predict(regime_features)

# Store GMM labels directly into df, aligning by index
df.loc[regime_features.index, 'GMM_Regime_Labels'] = gmm_regime_labels
# Fill NaNs that occur outside of regime_features.index (e.g., due to initial dropna) with -1, to be removed later.
df['GMM_Regime_Labels'] = df['GMM_Regime_Labels'].fillna(-1).astype(int)

probs = gmm.predict_proba(regime_features)

df.loc[regime_features.index, 'regime_low_vol'] = probs[:, 0]
df.loc[regime_features.index, 'regime_mid_vol'] = probs[:, 1]
df.loc[regime_features.index, 'regime_high_vol'] = probs[:, 2]

# %% [markdown]
# # VOLATILITY-AWARE TARGET

# %%
# Log returns
df['Return'] = np.log(df['Close'] / df['Close'].shift(1))

# Rolling volatility (20-day window)
df['Volatility'] = df['Return'].rolling(window=20).std()

df.dropna(inplace=True)

# %% [markdown]
# #Market Regime Detection (NOVEL)

# %%
from sklearn.cluster import KMeans

vol = df[['Volatility']]

# Market regime now uses 3 GMM components, not binary volatility threshold
# Ensure 'GMM_Regime_Labels' exists and is correctly populated from previous cell
df['Regime'] = df['GMM_Regime_Labels'] # Use the GMM labels (0, 1, 2, or -1 for initial NaNs)

# Label regimes (optional, update if necessary for visualization)
# The -1 will be dropped by subsequent dropna operations
df['Regime_Label'] = df['Regime'].map({0: 'Regime 0', 1: 'Regime 1', 2: 'Regime 2', -1: 'Unknown'})

# %%
# Create the primary target (future Close price)
df['Target_Close'] = df['Close'].shift(-1)
# Create future volatility and regime targets
df['Target_Volatility'] = df['Volatility'].shift(-1)
df['Target_Regime'] = df['Regime'].shift(-1)

# Drop any rows where features or the new target are NaN
df.dropna(inplace=True)

# %%
plt.figure(figsize=(15,5))
plt.plot(df.index, df['Close'])
plt.title('Gold Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(df.index, df['Close'], label='Gold Price')
plt.scatter(df.index, df['Close'], c=df['Regime'], cmap='coolwarm', s=10)
plt.title("Gold Price with Market Regimes")
plt.show()

# %% [markdown]
# # Scaling + Sequence Creation

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from sklearn.model_selection import train_test_split # Import train_test_split
from tensorflow.keras.utils import to_categorical # NEW: Import to_categorical
import tensorflow as tf # Import TensorFlow

features = ['Close', 'Open', 'High', 'Low', 'Volume', 'Volatility', 'Regime']

# Define the target features
target_feature_price = 'Target_Close'
target_feature_volatility = 'Target_Volatility'
target_feature_regime = 'Target_Regime'

# Create separate scalers for features (X) and targets (y)
scaler_X = MinMaxScaler()
scaled_X = scaler_X.fit_transform(df[features])

scaler_y_price = MinMaxScaler()
scaled_y_price = scaler_y_price.fit_transform(df[[target_feature_price]])

scaler_y_volatility = MinMaxScaler()
scaled_y_volatility = scaler_y_volatility.fit_transform(df[[target_feature_volatility]])

# NEW: For regime, we will use integer labels directly from df['Target_Regime']
# and then one-hot encode them. No scaler needed for regime labels.
y_regime_labels_raw = df[target_feature_regime].values.flatten() # Get raw labels as 1D array

# Modified create_multi_resolution_windows function to take X and Y separately
def create_multi_resolution_windows(X_data, y_price_data, y_vol_data, y_reg_data_labels_raw, short=7, mid=30, long=120):
    Xs, Xm, Xl, y_price_seq, y_vol_seq, y_reg_seq_labels_raw = [], [], [], [], [], []

    # Iterate through the data to create windows and corresponding targets
    # The target for a window ending at `i-1` is at `i`.
    # So the loop should go from `long` up to `len(X_data)`
    for i in range(long, len(X_data)):
        Xs.append(X_data[i-short:i]) # Window for short term features
        Xm.append(X_data[i-mid:i])   # Window for mid term features
        Xl.append(X_data[i-long:i])  # Window for long term features

        # Targets corresponding to the end of the window (i.e., predicting for index 'i')
        y_price_seq.append(y_price_data[i])
        y_vol_seq.append(y_vol_data[i])
        y_reg_seq_labels_raw.append(y_reg_data_labels_raw[i]) # Append raw integer labels

    return (
        np.array(Xs),
        np.array(Xm),
        np.array(Xl),
        np.array(y_price_seq),
        np.array(y_vol_seq),
        np.array(y_reg_seq_labels_raw) # Return raw integer labels
    )

# Call the modified function to get all sequences
Xs, Xm, Xl, y_price, y_vol, y_reg_labels_int = create_multi_resolution_windows(
    scaled_X, scaled_y_price, scaled_y_volatility, y_regime_labels_raw, # Pass 1D array
    short=7, mid=30, long=120
)

# NEW: One-hot encode the regime labels
# Assuming 3 classes (0, 1, 2) based on GMM_Regime_Labels
y_reg = to_categorical(y_reg_labels_int, num_classes=3)

# Perform train-test split for each resolution of features and all targets
# Use one split index for all data to maintain chronological order
split_index = int(len(Xs) * 0.8) # Assuming all X and y sequences have the same length

# Convert all numpy arrays to tf.Tensor with float32 dtype explicitly
X_train_s, X_val_s = tf.convert_to_tensor(Xs[:split_index], dtype=tf.float32), tf.convert_to_tensor(Xs[split_index:], dtype=tf.float32)
X_train_m, X_val_m = tf.convert_to_tensor(Xm[:split_index], dtype=tf.float32), tf.convert_to_tensor(Xm[split_index:], dtype=tf.float32)
X_train_l, X_val_l = tf.convert_to_tensor(Xl[:split_index], dtype=tf.float32), tf.convert_to_tensor(Xl[split_index:], dtype=tf.float32)

y_price_train, y_price_val = tf.convert_to_tensor(y_price[:split_index], dtype=tf.float32), tf.convert_to_tensor(y_price[split_index:], dtype=tf.float32)
y_vol_train, y_vol_val = tf.convert_to_tensor(y_vol[:split_index], dtype=tf.float32), tf.convert_to_tensor(y_vol[split_index:], dtype=tf.float32)
y_reg_train, y_reg_val = tf.convert_to_tensor(y_reg[:split_index], dtype=tf.float32), tf.convert_to_tensor(y_reg[split_index:], dtype=tf.float32)

# %% [markdown]
# # Multi-head Attention LSTM (Regime-Gated Attention)

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate, Attention
from tensorflow.keras.models import Model
import keras.ops as ops # Import keras.ops

input_s = Input(shape=(X_train_s.shape[1], X_train_s.shape[2]))
input_m = Input(shape=(X_train_m.shape[1], X_train_m.shape[2]))
input_l = Input(shape=(X_train_l.shape[1], X_train_l.shape[2]))

enc_s = LSTM(32, return_sequences=True)(input_s)
enc_m = LSTM(32, return_sequences=True)(input_m)
enc_l = LSTM(32, return_sequences=True)(input_l)

from tensorflow.keras.layers import Multiply, Softmax

# Regime gate (learned from long-term context)
regime_gate = Dense(3, activation='softmax', name='regime_gate')(enc_l[:, -1, :])

# Create attention heads
attn_s = Attention()([enc_s, enc_s])[:, -1, :]
attn_m = Attention()([enc_m, enc_m])[:, -1, :]
attn_l = enc_l[:, -1, :]

# Stack attention heads using keras.ops
attn_stack = ops.stack([attn_s, attn_m, attn_l], axis=1)

# Apply regime gate using keras.ops
gate_expanded = ops.expand_dims(regime_gate, axis=-1)
gated_context = ops.sum(attn_stack * gate_expanded, axis=1)


shared = Dense(64, activation='relu')(gated_context)

# Predict price distribution instead of point estimate
price_q10 = Dense(1, name='price_q10')(shared)
price_q50 = Dense(1, name='price_q50')(shared)
price_q90 = Dense(1, name='price_q90')(shared)
vol_out = Dense(1, name='volatility')(shared)
regime_out = Dense(3, activation='softmax', name='regime')(shared)

model = Model(
    inputs=[input_s, input_m, input_l],
    outputs=[price_q10, price_q50, price_q90, vol_out, regime_out]
)

def quantile_loss(q):
    def loss(y_true, y_pred):
        e = y_true - y_pred
        return tf.reduce_mean(tf.maximum(q * e, (q - 1) * e))
    return loss


model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss={
        'price_q10': quantile_loss(0.10),
        'price_q50': quantile_loss(0.50),
        'price_q90': quantile_loss(0.90),
        'volatility': 'mse',
        'regime': 'categorical_crossentropy' # Changed from sparse_categorical_crossentropy
    },
    metrics={
        'price_q50': ['mae'],
        'regime': ['accuracy']
    }
)


model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15      │ (None, 7, 7)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_16      │ (None, 30, 7)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_17      │ (None, 120, 7)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_15 (LSTM)      │ (None, 7, 32)     │      5,120 │ input_layer_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_16 (LSTM)      │ (None, 30, 32)    │      5,120 │ input_layer_16[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_17 (LSTM)      │ (None, 120, 32)   │      5,120 │ input_layer_17[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_9         │ (None, 7, 32)     │          0 │ lstm_15[0][0],    │
# │ (Attention)         │                   │            │ lstm_15[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_10        │ (None, 30, 32)    │          0 │ lstm_16[0][0],    │
# │ (Attention)         │                   │            │ lstm_16[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_18         │ (None, 32)        │          0 │ lstm_17[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_19         │ (None, 32)        │          0 │ attention_9[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_20         │ (None, 32)        │          0 │ attention_10[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_21         │ (None, 32)        │          0 │ lstm_17[0][0]     │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ regime_gate (Dense) │ (None, 3)         │         99 │ get_item_18[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_3 (Stack)     │ (None, 3, 32)     │          0 │ get_item_19[0][0… │
# │                     │                   │            │ get_item_20[0][0… │
# │                     │                   │            │ get_item_21[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_3       │ (None, 3, 1)      │          0 │ regime_gate[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 3, 32)     │          0 │ stack_3[0][0],    │
# │ (Multiply)          │                   │            │ expand_dims_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sum_3 (Sum)         │ (None, 32)        │          0 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      2,112 │ sum_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ price_q10 (Dense)   │ (None, 1)         │         65 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ price_q50 (Dense)   │ (None, 1)         │         65 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ price_q90 (Dense)   │ (None, 1)         │         65 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ volatility (Dense)  │ (None, 1)         │         65 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ regime (Dense)      │ (None, 3)         │        195 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,026 (70.41 KB)
#  Trainable params: 18,026 (70.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    [X_train_s, X_train_m, X_train_l],
    {
        'price_q10': y_price_train,
        'price_q50': y_price_train,
        'price_q90': y_price_train,
        'volatility': y_vol_train,
        'regime': y_reg_train
    },
    validation_data=(
        [X_val_s, X_val_m, X_val_l],
        {
            'price_q10': y_price_val,
            'price_q50': y_price_val,
            'price_q90': y_price_val,
            'volatility': y_vol_val,
            'regime': y_reg_val
        }
    ),
    epochs=30,
    batch_size=32
)
# Out:
# Epoch 1/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - loss: 0.9508 - price_q10_loss: 0.0167 - price_q50_loss: 0.0420 - price_q50_mae: 0.0840 - price_q90_loss: 0.0498 - regime_accuracy: 0.8705 - regime_loss: 0.7941 - volatility_loss: 0.0481 - val_loss: 0.7883 - val_price_q10_loss: 0.0491 - val_price_q50_loss: 0.0196 - val_price_q50_mae: 0.0369 - val_price_q90_loss: 0.1335 - val_regime_accuracy: 0.8109 - val_regime_loss: 0.6138 - val_volatility_loss: 0.0184
# Epoch 2/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.4429 - price_q10_loss: 0.0076 - price_q50_loss: 0.0053 - price_q50_mae: 0.0105 - price_q90_loss: 0.0056 - regime_accuracy: 0.8630 - regime_loss: 0.4178 - volatility_loss: 0.0066 - val_loss: 0.6165 - val_price_q10_loss: 0.0282 - val_price_q50_loss: 0.0351 - val_price_q50_mae: 0.0715 - val_price_q90_loss: 0.0560 - val_regime_accuracy: 0.8143 - val_regime_loss: 0.4961 - val_volatility_loss: 0.0261
# Epoch 3/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.3889 - price_q10_loss: 0.0029 - price_q50_loss: 0.0048 - price_q50_mae: 0.0097 - price_q90_loss: 0.0020 - regime_accuracy: 0.8763 - regime_loss: 0.3747 - volatility_loss: 0.0044 - val_loss: 0.5613 - val_price_q10_loss: 0.0208 - val_price_q50_loss: 0.0445 - val_price_q50_mae: 0.0858 - val_price_q90_loss: 0.0301 - val_regime_accuracy: 0.8279 - val_regime_loss: 0.4619 - val_volatility_loss: 0.0338
# Epoch 4/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - loss: 0.3935 - price_q10_loss: 0.0030 - price_q50_loss: 0.0035 - price_q50_mae: 0.0071 - price_q90_loss: 0.0022 - regime_accuracy: 0.8698 - regime_loss: 0.3809 - volatility_loss: 0.0039 - val_loss: 0.5271 - val_price_q10_loss: 0.0181 - val_price_q50_loss: 0.0298 - val_price_q50_mae: 0.0578 - val_price_q90_loss: 0.0300 - val_regime_accuracy: 0.8348 - val_regime_loss: 0.4596 - val_volatility_loss: 0.0179
# Epoch 5/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.3536 - price_q10_loss: 0.0021 - price_q50_loss: 0.0050 - price_q50_mae: 0.0100 - price_q90_loss: 0.0017 - regime_accuracy: 0.8847 - regime_loss: 0.3412 - volatility_loss: 0.0037 - val_loss: 0.5419 - val_price_q10_loss: 0.0190 - val_price_q50_loss: 0.0233 - val_price_q50_mae: 0.0467 - val_price_q90_loss: 0.0306 - val_regime_accuracy: 0.8501 - val_regime_loss: 0.4769 - val_volatility_loss: 0.0166
# Epoch 6/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 0.3466 - price_q10_loss: 0.0029 - price_q50_loss: 0.0033 - price_q50_mae: 0.0066 - price_q90_loss: 0.0020 - regime_accuracy: 0.8971 - regime_loss: 0.3354 - volatility_loss: 0.0030 - val_loss: 0.5104 - val_price_q10_loss: 0.0136 - val_price_q50_loss: 0.0192 - val_price_q50_mae: 0.0389 - val_price_q90_loss: 0.0381 - val_regime_accuracy: 0.8501 - val_regime_loss: 0.4530 - val_volatility_loss: 0.0119
# Epoch 7/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.3290 - price_q10_loss: 0.0025 - price_q50_loss: 0.0037 - price_q50_mae: 0.0074 - price_q90_loss: 0.0019 - regime_accuracy: 0.8982 - regime_loss: 0.3166 - volatility_loss: 0.0042 - val_loss: 0.5104 - val_price_q10_loss: 0.0125 - val_price_q50_loss: 0.0155 - val_price_q50_mae: 0.0295 - val_price_q90_loss: 0.0452 - val_regime_accuracy: 0.8603 - val_regime_loss: 0.4568 - val_volatility_loss: 0.0057
# Epoch 8/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.3524 - price_q10_loss: 0.0032 - price_q50_loss: 0.0044 - price_q50_mae: 0.0087 - price_q90_loss: 0.0024 - regime_accuracy: 0.8917 - regime_loss: 0.3345 - volatility_loss: 0.0080 - val_loss: 0.4656 - val_price_q10_loss: 0.0105 - val_price_q50_loss: 0.0190 - val_price_q50_mae: 0.0362 - val_price_q90_loss: 0.0397 - val_regime_accuracy: 0.8620 - val_regime_loss: 0.4157 - val_volatility_loss: 0.0092
# Epoch 9/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.3564 - price_q10_loss: 0.0019 - price_q50_loss: 0.0060 - price_q50_mae: 0.0120 - price_q90_loss: 0.0023 - regime_accuracy: 0.8910 - regime_loss: 0.3417 - volatility_loss: 0.0043 - val_loss: 0.4483 - val_price_q10_loss: 0.0109 - val_price_q50_loss: 0.0141 - val_price_q50_mae: 0.0258 - val_price_q90_loss: 0.0335 - val_regime_accuracy: 0.8586 - val_regime_loss: 0.4150 - val_volatility_loss: 0.0071
# Epoch 10/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.3546 - price_q10_loss: 0.0020 - price_q50_loss: 0.0038 - price_q50_mae: 0.0077 - price_q90_loss: 0.0018 - regime_accuracy: 0.8946 - regime_loss: 0.3429 - volatility_loss: 0.0041 - val_loss: 0.4626 - val_price_q10_loss: 0.0101 - val_price_q50_loss: 0.0218 - val_price_q50_mae: 0.0391 - val_price_q90_loss: 0.0657 - val_regime_accuracy: 0.8722 - val_regime_loss: 0.3905 - val_volatility_loss: 0.0085
# Epoch 11/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.3586 - price_q10_loss: 0.0018 - price_q50_loss: 0.0035 - price_q50_mae: 0.0071 - price_q90_loss: 0.0017 - regime_accuracy: 0.8863 - regime_loss: 0.3458 - volatility_loss: 0.0057 - val_loss: 0.4746 - val_price_q10_loss: 0.0102 - val_price_q50_loss: 0.0274 - val_price_q50_mae: 0.0506 - val_price_q90_loss: 0.0564 - val_regime_accuracy: 0.8671 - val_regime_loss: 0.4129 - val_volatility_loss: 0.0072
# Epoch 12/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 0.3360 - price_q10_loss: 0.0023 - price_q50_loss: 0.0042 - price_q50_mae: 0.0084 - price_q90_loss: 0.0017 - regime_accuracy: 0.8975 - regime_loss: 0.3237 - volatility_loss: 0.0040 - val_loss: 0.4553 - val_price_q10_loss: 0.0101 - val_price_q50_loss: 0.0253 - val_price_q50_mae: 0.0461 - val_price_q90_loss: 0.0539 - val_regime_accuracy: 0.8825 - val_regime_loss: 0.3872 - val_volatility_loss: 0.0143
# Epoch 13/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.3192 - price_q10_loss: 0.0027 - price_q50_loss: 0.0042 - price_q50_mae: 0.0083 - price_q90_loss: 0.0026 - regime_accuracy: 0.9036 - regime_loss: 0.3062 - volatility_loss: 0.0035 - val_loss: 0.4524 - val_price_q10_loss: 0.0121 - val_price_q50_loss: 0.0209 - val_price_q50_mae: 0.0373 - val_price_q90_loss: 0.0671 - val_regime_accuracy: 0.8842 - val_regime_loss: 0.3791 - val_volatility_loss: 0.0066
# Epoch 14/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.3125 - price_q10_loss: 0.0022 - price_q50_loss: 0.0038 - price_q50_mae: 0.0076 - price_q90_loss: 0.0015 - regime_accuracy: 0.9046 - regime_loss: 0.3015 - volatility_loss: 0.0033 - val_loss: 0.4524 - val_price_q10_loss: 0.0085 - val_price_q50_loss: 0.0227 - val_price_q50_mae: 0.0402 - val_price_q90_loss: 0.0721 - val_regime_accuracy: 0.8739 - val_regime_loss: 0.3764 - val_volatility_loss: 0.0055
# Epoch 15/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 106ms/step - loss: 0.3082 - price_q10_loss: 0.0015 - price_q50_loss: 0.0033 - price_q50_mae: 0.0066 - price_q90_loss: 0.0025 - regime_accuracy: 0.9086 - regime_loss: 0.2975 - volatility_loss: 0.0033 - val_loss: 0.4723 - val_price_q10_loss: 0.0118 - val_price_q50_loss: 0.0246 - val_price_q50_mae: 0.0438 - val_price_q90_loss: 0.0754 - val_regime_accuracy: 0.8790 - val_regime_loss: 0.3896 - val_volatility_loss: 0.0062
# Epoch 16/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.2982 - price_q10_loss: 0.0023 - price_q50_loss: 0.0029 - price_q50_mae: 0.0059 - price_q90_loss: 0.0014 - regime_accuracy: 0.9104 - regime_loss: 0.2886 - volatility_loss: 0.0030 - val_loss: 0.4695 - val_price_q10_loss: 0.0096 - val_price_q50_loss: 0.0252 - val_price_q50_mae: 0.0448 - val_price_q90_loss: 0.0694 - val_regime_accuracy: 0.8739 - val_regime_loss: 0.3888 - val_volatility_loss: 0.0054
# Epoch 17/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 0.3292 - price_q10_loss: 0.0016 - price_q50_loss: 0.0035 - price_q50_mae: 0.0070 - price_q90_loss: 0.0017 - regime_accuracy: 0.8944 - regime_loss: 0.3192 - volatility_loss: 0.0032 - val_loss: 0.4623 - val_price_q10_loss: 0.0107 - val_price_q50_loss: 0.0272 - val_price_q50_mae: 0.0485 - val_price_q90_loss: 0.0687 - val_regime_accuracy: 0.8807 - val_regime_loss: 0.3852 - val_volatility_loss: 0.0053
# Epoch 18/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.3294 - price_q10_loss: 0.0020 - price_q50_loss: 0.0029 - price_q50_mae: 0.0057 - price_q90_loss: 0.0017 - regime_accuracy: 0.8935 - regime_loss: 0.3199 - volatility_loss: 0.0029 - val_loss: 0.4630 - val_price_q10_loss: 0.0123 - val_price_q50_loss: 0.0308 - val_price_q50_mae: 0.0554 - val_price_q90_loss: 0.0598 - val_regime_accuracy: 0.8790 - val_regime_loss: 0.3884 - val_volatility_loss: 0.0076
# Epoch 19/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.3144 - price_q10_loss: 0.0029 - price_q50_loss: 0.0026 - price_q50_mae: 0.0053 - price_q90_loss: 0.0014 - regime_accuracy: 0.9046 - regime_loss: 0.3046 - volatility_loss: 0.0028 - val_loss: 0.4432 - val_price_q10_loss: 0.0093 - val_price_q50_loss: 0.0238 - val_price_q50_mae: 0.0421 - val_price_q90_loss: 0.0646 - val_regime_accuracy: 0.8790 - val_regime_loss: 0.3744 - val_volatility_loss: 0.0050
# Epoch 20/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.3114 - price_q10_loss: 0.0017 - price_q50_loss: 0.0037 - price_q50_mae: 0.0075 - price_q90_loss: 0.0014 - regime_accuracy: 0.9050 - regime_loss: 0.3021 - volatility_loss: 0.0026 - val_loss: 0.4490 - val_price_q10_loss: 0.0088 - val_price_q50_loss: 0.0263 - val_price_q50_mae: 0.0465 - val_price_q90_loss: 0.0685 - val_regime_accuracy: 0.8790 - val_regime_loss: 0.3715 - val_volatility_loss: 0.0050
# Epoch 21/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.3036 - price_q10_loss: 0.0014 - price_q50_loss: 0.0032 - price_q50_mae: 0.0063 - price_q90_loss: 0.0018 - regime_accuracy: 0.9062 - regime_loss: 0.2941 - volatility_loss: 0.0031 - val_loss: 0.4505 - val_price_q10_loss: 0.0097 - val_price_q50_loss: 0.0300 - val_price_q50_mae: 0.0538 - val_price_q90_loss: 0.0653 - val_regime_accuracy: 0.8756 - val_regime_loss: 0.3741 - val_volatility_loss: 0.0055
# Epoch 22/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.3081 - price_q10_loss: 0.0013 - price_q50_loss: 0.0026 - price_q50_mae: 0.0052 - price_q90_loss: 0.0016 - regime_accuracy: 0.9059 - regime_loss: 0.2993 - volatility_loss: 0.0032 - val_loss: 0.4571 - val_price_q10_loss: 0.0089 - val_price_q50_loss: 0.0291 - val_price_q50_mae: 0.0517 - val_price_q90_loss: 0.0700 - val_regime_accuracy: 0.8825 - val_regime_loss: 0.3692 - val_volatility_loss: 0.0117
# Epoch 23/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.3265 - price_q10_loss: 0.0015 - price_q50_loss: 0.0033 - price_q50_mae: 0.0067 - price_q90_loss: 0.0013 - regime_accuracy: 0.8981 - regime_loss: 0.3159 - volatility_loss: 0.0044 - val_loss: 0.4671 - val_price_q10_loss: 0.0095 - val_price_q50_loss: 0.0343 - val_price_q50_mae: 0.0619 - val_price_q90_loss: 0.0743 - val_regime_accuracy: 0.8790 - val_regime_loss: 0.3740 - val_volatility_loss: 0.0051
# Epoch 24/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.2967 - price_q10_loss: 0.0017 - price_q50_loss: 0.0028 - price_q50_mae: 0.0056 - price_q90_loss: 0.0015 - regime_accuracy: 0.9182 - regime_loss: 0.2876 - volatility_loss: 0.0030 - val_loss: 0.4494 - val_price_q10_loss: 0.0082 - val_price_q50_loss: 0.0302 - val_price_q50_mae: 0.0540 - val_price_q90_loss: 0.0670 - val_regime_accuracy: 0.8807 - val_regime_loss: 0.3703 - val_volatility_loss: 0.0056
# Epoch 25/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.3096 - price_q10_loss: 0.0013 - price_q50_loss: 0.0033 - price_q50_mae: 0.0065 - price_q90_loss: 0.0014 - regime_accuracy: 0.9057 - regime_loss: 0.3011 - volatility_loss: 0.0026 - val_loss: 0.4652 - val_price_q10_loss: 0.0095 - val_price_q50_loss: 0.0320 - val_price_q50_mae: 0.0575 - val_price_q90_loss: 0.0667 - val_regime_accuracy: 0.8773 - val_regime_loss: 0.3834 - val_volatility_loss: 0.0046
# Epoch 26/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.3039 - price_q10_loss: 0.0018 - price_q50_loss: 0.0029 - price_q50_mae: 0.0057 - price_q90_loss: 0.0013 - regime_accuracy: 0.9065 - regime_loss: 0.2954 - volatility_loss: 0.0026 - val_loss: 0.4375 - val_price_q10_loss: 0.0094 - val_price_q50_loss: 0.0295 - val_price_q50_mae: 0.0524 - val_price_q90_loss: 0.0546 - val_regime_accuracy: 0.8825 - val_regime_loss: 0.3681 - val_volatility_loss: 0.0080
# Epoch 27/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.3141 - price_q10_loss: 0.0017 - price_q50_loss: 0.0031 - price_q50_mae: 0.0063 - price_q90_loss: 0.0020 - regime_accuracy: 0.9091 - regime_loss: 0.3044 - volatility_loss: 0.0029 - val_loss: 0.4518 - val_price_q10_loss: 0.0100 - val_price_q50_loss: 0.0296 - val_price_q50_mae: 0.0529 - val_price_q90_loss: 0.0645 - val_regime_accuracy: 0.8842 - val_regime_loss: 0.3719 - val_volatility_loss: 0.0097
# Epoch 28/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.2951 - price_q10_loss: 0.0019 - price_q50_loss: 0.0029 - price_q50_mae: 0.0059 - price_q90_loss: 0.0017 - regime_accuracy: 0.9042 - regime_loss: 0.2856 - volatility_loss: 0.0030 - val_loss: 0.4466 - val_price_q10_loss: 0.0077 - val_price_q50_loss: 0.0297 - val_price_q50_mae: 0.0527 - val_price_q90_loss: 0.0615 - val_regime_accuracy: 0.8825 - val_regime_loss: 0.3728 - val_volatility_loss: 0.0089
# Epoch 29/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - loss: 0.3074 - price_q10_loss: 0.0015 - price_q50_loss: 0.0034 - price_q50_mae: 0.0067 - price_q90_loss: 0.0018 - regime_accuracy: 0.9035 - regime_loss: 0.2983 - volatility_loss: 0.0023 - val_loss: 0.4539 - val_price_q10_loss: 0.0085 - val_price_q50_loss: 0.0336 - val_price_q50_mae: 0.0601 - val_price_q90_loss: 0.0691 - val_regime_accuracy: 0.8807 - val_regime_loss: 0.3700 - val_volatility_loss: 0.0052
# Epoch 30/30
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.3037 - price_q10_loss: 0.0015 - price_q50_loss: 0.0026 - price_q50_mae: 0.0051 - price_q90_loss: 0.0016 - regime_accuracy: 0.9135 - regime_loss: 0.2957 - volatility_loss: 0.0023 - val_loss: 0.4572 - val_price_q10_loss: 0.0095 - val_price_q50_loss: 0.0330 - val_price_q50_mae: 0.0590 - val_price_q90_loss: 0.0727 - val_regime_accuracy: 0.8807 - val_regime_loss: 0.3675 - val_volatility_loss: 0.0068

# %%
pred_q10, pred_q50, pred_q90, pred_vol, pred_reg = model.predict(
    [X_val_s, X_val_m, X_val_l]
)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step

# %%
# Convert tensors to numpy
y_price_val_np = y_price_val.numpy()
y_vol_val_np   = y_vol_val.numpy()
y_reg_val_np   = y_reg_val.numpy()

pred_price_np = pred_price
pred_vol_np   = pred_vol
pred_reg_np   = pred_reg

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

price_mae = mean_absolute_error(y_price_val_np, pred_price_np)
price_rmse = np.sqrt(mean_squared_error(y_price_val_np, pred_price_np))

print(f"Price MAE  : {price_mae:.4f}")
print(f"Price RMSE : {price_rmse:.4f}")
# Out:
# Price MAE  : 0.0585
# Price RMSE : 0.0936

# %%
vol_mae = mean_absolute_error(y_vol_val_np, pred_vol_np)
print(f"Volatility MAE : {vol_mae:.4f}")
# Out:
# Volatility MAE : 0.0576

# %%
from sklearn.metrics import accuracy_score

true_regime = np.argmax(y_reg_val_np, axis=1)
pred_regime = np.argmax(pred_reg_np, axis=1)

regime_acc = accuracy_score(true_regime, pred_regime)
print(f"Regime Classification Accuracy: {regime_acc:.4f}")
# Out:
# Regime Classification Accuracy: 0.8807

# %%
plt.figure(figsize=(15,5))
plt.plot(y_price_val, label='Actual Price')
plt.plot(pred_price, label='Predicted Price')
plt.title('Actual vs Predicted Gold Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(y_vol_val, label='Actual Volatility')
plt.plot(pred_vol, label='Predicted Volatility')
plt.title('Volatility Prediction')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,3))
plt.plot(true_regime, label='Actual Regime')
plt.plot(pred_regime, alpha=0.7, label='Predicted Regime')
plt.title('Market Regime Detection')
plt.legend()
plt.show()

# %%
val_dates = df.index[-len(y_price_val):]

plt.figure(figsize=(15,5))
plt.plot(val_dates, y_price_val, label='Price')

plt.scatter(
    val_dates,
    y_price_val,
    c=y_reg_val,
    cmap='coolwarm',
    s=10,
    label='Regime'
)

plt.title('Gold Price with Market Regimes')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# /tmp/ipython-input-2451864574.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
val_dates = df.index[-len(y_price_val_np):]

recent_mask = val_dates >= pd.Timestamp('2022-01-01')

recent_mae = mean_absolute_error(
    y_price_val_np[recent_mask],
    pred_price_np[recent_mask]
)

print("Recent Period MAE:", recent_mae)
# Out:
# Recent Period MAE: 0.058459825813770294

# %% [markdown]
# # ATTENTION-BASED LSTM

# %% [markdown]
# # QUANTILE REGRESSION

# %%
def quantile_loss(q):
    def loss(y_true, y_pred):
        e = y_true - y_pred
        return tf.reduce_mean(tf.maximum(q*e, (q-1)*e))
    return loss

# %%
model.compile(
    optimizer='adam',
    loss={
        'price_q10': quantile_loss(0.1),
        'price_q50': quantile_loss(0.5),
        'price_q90': quantile_loss(0.9),
        'volatility': 'mse',
        'regime': 'categorical_crossentropy'
    },
    loss_weights={
        'price_q10': 0.2,
        'price_q50': 0.4,
        'price_q90': 0.2,
        'volatility': 0.1,
        'regime': 0.1
    }
)

# %%
# Interval coverage
lower = pred_q10
upper = pred_q90
true = y_price_val_np

picp = np.mean((true >= lower) & (true <= upper))
mpiw = np.mean(upper - lower)

print(f"PICP (coverage): {picp:.3f}")
print(f"MPIW (interval width): {mpiw:.3f}")
# Out:
# PICP (coverage): 0.107
# MPIW (interval width): 0.017

# %%
plt.figure(figsize=(15,5))
plt.plot(true, label='Actual', color='black')
plt.plot(pred_q50, label='Median Prediction')
plt.fill_between(
    range(len(true)),
    pred_q10.flatten(),
    pred_q90.flatten(),
    alpha=0.3,
    label='Uncertainty Band'
)
plt.legend()
plt.title('Gold Price Forecast with Uncertainty (AURUM-Net)')
plt.show()
